# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install -qU langchain
# !pip install -qU langchain-google-genai
# !pip install -qU langchain-huggingface
# !pip install -qU langchain-qdrant
# !pip install -qU langchain-community
# !pip install -qU langgraph
# !pip install fastembed
# !pip install datasets
# !pip install -U "fsspec[http]==2024.10.0"
# !pip install fastapi 
# !pip install uvicorn

# %%
# %%capture
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import torch
from tqdm import tqdm

from IPython.display import display

from sklearn.utils import resample
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer

# %% [markdown]
# # Components

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash-001")

# %%
os.environ["LANGSMITH_TRACING_V2"] = "true"
os.environ["LANGSMITH_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGSMITH_API_KEY"] = userdata.get('langsmith_api_key')
os.environ["LANGSMITH_PROJECT"] = "DSDE-Project"

# %% [markdown]
# # Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! ls 'drive/MyDrive/Data Sci 2025/Final_Project/Final Project/'
# Out:
# bangkok_traffy.csv  df_for_ds.csv  handred_thousand.csv
# DataEng.ipynb	    full_col.csv   minidf_notype.csv

# %%
dataset_path = 'drive/MyDrive/Data Sci 2025/Final_Project/Final Project/'
ds = pd.read_csv(dataset_path + "handred_thousand.csv")

# %% [markdown]
# # Embedding Model

# %%
"""
"KanisornPutta/CeltaVigoBert"
"clicknext/phayathaibert"
"KanisornPutta/TrentIsNotFuckingLeavingBERT"
"""
# Out:
# '\n"KanisornPutta/CeltaVigoBert"\n"clicknext/phayathaibert"\n"KanisornPutta/TrentIsNotFuckingLeavingBERT"\n'

# %%
from langchain_huggingface import HuggingFaceEmbeddings

model_kwargs = {'trust_remote_code': True}
embeddings = HuggingFaceEmbeddings(model_name="KanisornPutta/TrentIsNotFuckingLeavingBERT",model_kwargs=model_kwargs)

# %%
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import CrossEncoderReranker
from langchain_community.cross_encoders import HuggingFaceCrossEncoder

model = HuggingFaceCrossEncoder(model_name="Pongsasit/mod-th-cross-encoder-minilm")

# %% [markdown]
# ## Data Preparation

# %%
ds.head(3)
# Out:
#      ticket_id              type  \
# 0  2024-HDE8AM  {เสียงรบกวน,ถนน}
# 1  2023-E4NQUH             {ถนน}
# 2  2024-VR89N3             {ถนน}
#
#                                         organization  \
# 0  กองโครงการสายอากาศเป็นสายใต้ดิน2 ฝ่ายบริหารโคร...
# 1                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2  เขตบางซื่อ,สำนักการโยธา กทม.,สำนักงานวิศวกรรมท...
#
#                                              comment  \
# 0  แผ่นเหล็กปิดถนนขั่วคราวปิดไม่เรียบร้อย เกิดเสี...
# 1  https://youtu.be/7ly_Zgk-8Co\n\nดูจบแล้วน่าสนใ...
# 2  พบปัญหายางมะตอยที่ราดบนสะพานหลุดล่อนทำให้เกิดร...
#
#                                                photo  \
# 0  https://storage.googleapis.com/traffy_public_b...
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 0  https://storage.googleapis.com/traffy_public_b...  100.65690,13.76710
# 1  https://storage.googleapis.com/traffy_public_b...  100.69469,13.71739
# 2                                                NaN  100.53901,13.83039
#
#                                              address subdistrict district  \
# 0  968 ถนน รามคำแหง หัวหมาก เขตบางกะปิ กรุงเทพมหา...     หัวหมาก  บางกะปิ
# 1  33 เฉลิมพระเกีรยติ ร.9 ซอย 81 แขวงประเวศ เขต ป...      ประเวศ   ประเวศ
# 2  51 ถ. รัชดาภิเษก แขวง วงศ์สว่าง เขตบางซื่อ กรุ...   วงศ์สว่าง  บางซื่อ
#
#         province                      timestamp           state  star  \
# 0  กรุงเทพมหานคร  2024-07-06 01:26:42.908463+00       เสร็จสิ้น   NaN
# 1  กรุงเทพมหานคร  2023-05-02 14:35:58.588305+00       เสร็จสิ้น   NaN
# 2  กรุงเทพมหานคร  2024-05-25 10:23:11.112647+00  กำลังดำเนินการ   NaN
#
#    count_reopen                  last_activity        type_str  \
# 0             0  2024-11-06 02:00:11.876998+00  เสียงรบกวน,ถนน
# 1             0   2023-07-14 07:33:28.60558+00             ถนน
# 2             0  2024-05-26 04:32:04.804649+00             ถนน
#
#                 type_set
# 0  {'ถนน', 'เสียงรบกวน'}
# 1                {'ถนน'}
# 2                {'ถนน'}

# %%
ds['comment'][4]
# Out:
# 'ทางเท้า หน้าร้านอาหาร ซอยสุขุมวิท23 สกปรก โสโครกมากก ร้านค้าเทสิ่งปฏิกูลลงท่อ ลงทางเท้า ร้องเรียนไปหลายครั้งมากๆๆๆ จนรำคาญการทำงานของเจ้าหน้าที่ ที่ไม่ทำ***อะไรเลย ช่วยไปทำความสะอาด และปรับร้านค้าด้วย ฟรือต้องให้ร้องเรียนแบบนี้ทุกวัน ทำงานบ้างเถอะ'

# %%
ds['address'][4]
# Out:
# '4 7 ซ. สุขุมวิท 23 แขวงคลองเตยเหนือ เขตวัฒนา กรุงเทพมหานคร 10110 ประเทศไทย'

# %%
ds['photo'][0]
# Out:
# 'https://storage.googleapis.com/traffy_public_bucket/attachment/2024-07/198951fea260fcf8e727e50942bd35519fc3fa6a.jpg'

# %%
import re

def clean_comment(comment):

    if type(comment) != str :
      return ""

    # comment = ''.join([' ' if c.isdigit() else c for c in comment])
    comment = ''.join([c for c in comment if c.isalpha() or c.isspace() or '\u0E00' <= c <= '\u0E7F'])
    comment = comment.replace('\n', ' ')
    comment = comment.replace('\r', ' ')
    comment = re.sub(' +', ' ', comment)  # replaces multiple spaces with one

    return comment

# %%
def seperate_text(text):
    if type(text) != str :
      return ""
    return text.replace(",", ", ")

# %%
ds['type_str'] = ds['type_str'].apply(seperate_text)

# %%
ds['type_str'][0]
# Out:
# 'เสียงรบกวน, ถนน'

# %%
ds.shape
# Out:
# (100000, 18)

# %%
ds.dropna(subset=['comment'], inplace=True)

# %%
ds.shape
# Out:
# (99035, 18)

# %%
ds['context'] = ds.apply(
    lambda row: f'ชนิด: {seperate_text(row["type_str"])} : "{clean_comment(row["comment"])}" ที่อยู่ "{clean_comment(row["address"])}"',
    axis=1
)

# %%
ds.loc[4]
# Out:
# ticket_id                                              2024-E7E2VX
# type                                           {ร้องเรียน,ทางเท้า}
# organization     เขตวัฒนา,ฝ่ายเทศกิจ เขตวัฒนา,ฝ่ายสิ่งแวดล้อมฯ ...
# comment          ทางเท้า หน้าร้านอาหาร ซอยสุขุมวิท23 สกปรก โสโค...
# photo            https://storage.googleapis.com/traffy_public_b...
# photo_after      https://storage.googleapis.com/traffy_public_b...
# coords                                          100.56279,13.73644
# address          4 7 ซ. สุขุมวิท 23 แขวงคลองเตยเหนือ เขตวัฒนา ก...
# subdistrict                                           คลองเตยเหนือ
# district                                                     วัฒนา
# province                                             กรุงเทพมหานคร
# timestamp                            2024-04-26 01:40:43.834504+00
# state                                                    เสร็จสิ้น
# star                                                           NaN
# count_reopen                                                     0
# last_activity                        2024-06-20 09:47:08.276558+00
# type_str                                        ร้องเรียน, ทางเท้า
# type_set                                  {'ทางเท้า', 'ร้องเรียน'}
# context          ชนิด: ร้องเรียน,  ทางเท้า : "ทางเท้า หน้าร้านอ...
# Name: 4, dtype: object

# %%
ds['context'][4]
# Out:
# 'ชนิด: ร้องเรียน,  ทางเท้า : "ทางเท้า หน้าร้านอาหาร ซอยสุขุมวิท สกปรก โสโครกมากก ร้านค้าเทสิ่งปฏิกูลลงท่อ ลงทางเท้า ร้องเรียนไปหลายครั้งมากๆๆๆ จนรำคาญการทำงานของเจ้าหน้าที่ ที่ไม่ทำอะไรเลย ช่วยไปทำความสะอาด และปรับร้านค้าด้วย ฟรือต้องให้ร้องเรียนแบบนี้ทุกวัน ทำงานบ้างเถอะ" ที่อยู่ " ซ สุขุมวิท แขวงคลองเตยเหนือ เขตวัฒนา กรุงเทพมหานคร ประเทศไทย"'

# %%
from langchain_core.documents import Document

# %%
all_docs = []

for index, row in ds.iterrows(): # Use iterrows() for index-safe iteration
    context = row["context"]
    problem_type = row["type_str"]  # Get values directly from the row
    address = row["address"]
    ticket_id = row["ticket_id"]
    comment = row["comment"]

    if context is not None:
        doc = Document(
            page_content=str(context),
            metadata={
                "problem_type": problem_type,
                "address": address,
                "ticket_id": ticket_id
            }
        )
        all_docs.append(doc)

print(len(all_docs))
# Out:
# 99035

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(all_docs)

print(f"Split wiki abstract into {len(all_splits)} sub-documents.")
# Out:
# Split wiki abstract into 99417 sub-documents.

# %%
all_splits[0]
# Out:
# Document(metadata={'problem_type': 'เสียงรบกวน, ถนน', 'address': '968 ถนน รามคำแหง หัวหมาก เขตบางกะปิ กรุงเทพมหานคร 10240 ประเทศไทย', 'ticket_id': '2024-HDE8AM', 'start_index': 0}, page_content='ชนิด: เสียงรบกวน,  ถนน : "แผ่นเหล็กปิดถนนขั่วคราวปิดไม่เรียบร้อย เกิดเสียงดังทุกครั้งที่รถวิ่งผ่าน เป็นอันคราบต่อผู้ใช้ถนน" ที่อยู่ " ถนน รามคำแหง หัวหมาก เขตบางกะปิ กรุงเทพมหานคร ประเทศไทย"')

# %% [markdown]
# ## Vector Database
# Embed your documents in a vector database that supports hybrid search. Also set the retrieval mode to hybrid search.
#
# We will use `QdrantVectorStore` [Learn more here](https://python.langchain.com/api_reference/qdrant/qdrant/langchain_qdrant.qdrant.QdrantVectorStore.html#langchain_qdrant.qdrant.QdrantVectorStore). (You can use any vector DB that can do hybrid search)

# %%
from tqdm import tqdm

# %%
from langchain_qdrant import FastEmbedSparse, QdrantVectorStore, RetrievalMode
from qdrant_client import QdrantClient, models
from qdrant_client.http.models import Distance, SparseVectorParams, VectorParams

sparse_embeddings = FastEmbedSparse(model_name="Qdrant/bm25")

# Create a Qdrant client for local storage
# client = QdrantClient(":memory:")
client = QdrantClient(path="./qdrant_storage")

# Create a collection with both dense and sparse vectors
client.create_collection(
    collection_name="my_documents",
    vectors_config={"dense": VectorParams(size=768, distance=Distance.COSINE)},
    sparse_vectors_config={
        "sparse": SparseVectorParams(index=models.SparseIndexParams(on_disk=False))
    },
)

qdrant = QdrantVectorStore(
    client=client,
    collection_name="my_documents",
    embedding=embeddings,
    sparse_embedding=sparse_embeddings,
    retrieval_mode=RetrievalMode.HYBRID,
    vector_name="dense",
    sparse_vector_name="sparse",
)

print("Adding documents to Qdrant...")
for doc in tqdm(all_splits, desc="Uploading documents"):
    qdrant.add_documents(documents=[doc])  # Process one document at a time

query = "น้ำท่วม"
found_docs = qdrant.similarity_search(query)
found_docs

# %% [markdown]
# ### Download vector Database

# %%
# !zip -r qdrant_storage.zip qdrant_storage
# Out:
#   adding: qdrant_storage/ (stored 0%)
#   adding: qdrant_storage/.lock (stored 0%)
#   adding: qdrant_storage/collection/ (stored 0%)
#   adding: qdrant_storage/collection/my_documents/ (stored 0%)
#   adding: qdrant_storage/collection/my_documents/storage.sqlite (deflated 55%)
#   adding: qdrant_storage/meta.json (deflated 59%)

# %%
from google.colab import files
files.download("qdrant_storage.zip")

# %% [markdown]
# # Retrievers

# %%
retriever = qdrant.as_retriever(search_kwargs={"k": 10})

# %%
reranker = CrossEncoderReranker(model=model, top_n=10)
reranked_retriever = ContextualCompressionRetriever(
    base_compressor=reranker , base_retriever=retriever
)

# %% [markdown]
# Take a subset of the dataset to evaluate the MRR of the retrievers.

# %%
#sample = ds.take(1000)

# %%
test_query = "เขตจตุจักรมีปัญหาเกี่ยวกับอะไรมากที่สุด?"

# %%
test_docs = retriever.get_relevant_documents(test_query)
print(f'query : {test_query}')
print('-'*30)
for doc in test_docs[:10] :
  print(f'- {doc.page_content}')
# Out:
# <ipython-input-36-834d686a6aae>:1: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   test_docs = retriever.get_relevant_documents(test_query)
# query : เขตจตุจักรมีปัญหาเกี่ยวกับอะไรมากที่สุด?
# ------------------------------
# - การเป็นพยาน หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตบางแค ซอย กาญจนาภิเษก แยก แขวงบางแค เขตบางแค กรุงเทพมหานคร ซอย กาญจนาภิเษก แยก แขวงบางแค เขตบางแค กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ร้องเรียน : "ขอเรียนแจ้งปัญหาเกี่ยวกับการทำงานของผู้รับเหมา น่าจะเป็น TOT มีการทำงานที่ไม่เรียบร้อย ส่งผลให้ฝรั่งนักท่องเที่ยวหยุดถ่ายรูปหลายครั้ง ปัญหาเมือง" ที่อยู่ "Opposite Baan Klang Muang Lat Phrao แขวง จันทรเกษม เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตพญาไท ซอย อารีย์ แขวง พญาไท เขตพญาไท กรุงเทพมหานคร ซอย อารีย์ แขวง พญาไท เขตพญาไท กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ถนน : "ตลาดนัดจตุจักร เรียนผู้ว่ากทม ขอให้ตรวจสอบกรณีวันที่กค ณห้องประชุมตลาดนัดจตุจักร มีชมรมผู้ค้ากลุ่มนึงเข้ามาส่งจดหมายติดตาม คำสั่งจากปลัดกรุงเทพมหานคร ที่สั่งให้มีการทดลองจอดรถในตลาดนัดจตุจักรทั้งวันเป็นเวลาเดือนกค ถึง กย ว่าเป็นคำสั่งที่ชอบธรรมหรือไม่ และเอากฎระเบียบข้อไหนมารองรับ โดยผู้ค้ากลุ่มนี้อ้างว่าถ้าให้รถจอดริมถนนรอบตลาดนัดแล้วจะทำให้ลูกค้าเดินเข้าไปด้านในทำให้ด้านในขายดีขึ้น เป็นการพิจารณาที่รับฟังความข้างเดียว เป็นการแก้ปัญหาที่ไม่ตรงจุด ปัจจุบันการค้าขายรอบๆถนนในตลาดนัดจตุจักรกำลังเริ่มคึกคักหลังจากรัฐบาลมีมาตรการผ่อนปรนโรคโควิด นักท่องเที่ยวกำลังกลับมาจับจ่ายใช้สอย แต่คำสั่งดังกล่าวจะเป็นการทำลายวิถีอัตลักษณ์การเป็นตลาดนัดจตุจักรในสายตานักท่องเที่ยวหลักชาวต่างชาติ ขออย่าแก้ปัญหาที่ลูกค้าไม่เดินเข้าด้านในโดยการสร้างปัญหาให้ส่วนที่ดีอยู่แล้วให้เกิดผลเสียเพิ่มขึ้น การแก้ปัญหาที่ส่วนไหนลูกค้าไม่เดินเข้าไปต้องเพิ่มสิ่งดึงดูดที่น่าสนใจ ชักจูงจิตใจให้อยากที่จะเข้าไปด้านใน ไม่ใช่สร้างอุปสรรคขัดขวางเพื่อให้ต้องหลบไปอีกที่ ด้านในตลาดนัดจตุจักรมีหอนาฬิกาเป็นแลนด์มาร์ค มีพื้นที่ว่างลานเล่รอบหอนาฬิกา แต่การบริหารไม่สามารถใช้ศักยภาพจากจุดนี้ดึงลูกค้าเข้าด้านในได้ ถ้าสามารถใช้ประโยชน์จากส่วนนี้อย่างเต็มที่ จะเป็นการแก้ปัญหาภายในตลาดนัดจตุจักรที่ไม่กระทบกับส่วนรวมอื่นๆเลย" ที่อยู่ " ถนน กำแพงเพชร แขวง จตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - อย่างนี้ถือว่าปฎิบัติหน้าที่โดยมิชอบหรือไม่ อยากจะให้ทางพรรคก้าวไกล ในฐานะที่มีท่านสสเท่าพิภพเป็นสสเขตนี้ ช่วงดูแลด้วย" ที่อยู่ "สำนักงานเขตบางกอกใหญ่ แขวง วัดท่าพระ เขตบางกอกใหญ่ กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ต้นไม้,  แสงสว่าง,  ถนน,  คลอง : "ปัญหา ต้นไม้และสวนสาธารณะ เนื่องจาก ผู้แจ้งต้องการให้เจ้าหน้าที่ไปตัดแต่งต้นไม้ ซึ่งเป็นต้นไม้สาธารณะ ต้นไม้บดบังแสงสว่างจากไฟทาง จึงอยากให้ตัดแต่งต้นไม้ทั้ง ฝั่ง อยู่ตรงบริเวณหัวมุมบ้าน ต้นไม้ขึ้นสูงแล้วไปพันเกี่ยวกับสายไฟฟ้า ขอให้ดำเนินการตรวจสอบและแก้ไขปัญหานี้ด้วย จุดเกิดเหตุ สถานที่สำคัญ จุดสังเกต หมู่บ้านประชานิเวศน์ ฝั่งตรงข้ามกับคลองประปา บ้านผู้แจ้งจะอยู่ฝั่งเดียวกันกับสำนักงานประกันสังคม บ้านปูด้วยกระเบื้องสีส้ม บ้านเลขที่ ซอย ถนน เทศบาลรังสรรค์เหนือ แขวง ลาดยาว เขต จตุจักร " ที่อยู่ " ถนน เทศบาลนิมิตรเหนือ แขวงลาดยาว เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตวังทองหลาง ซอย รามคำแหง แขวงพลับพลา เขตวังทองหลาง กรุงเทพมหานคร ซ รามคำแหง แขวงพลับพลา เขตวังทองหลาง กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ร้องเรียน,  ทางเท้า : "ป้ายโฆษณาคอนโดฯตั้งบนทางเท้ากลับมาอีกแล้วหายไปอาทิตย์เดียวก็มาเหมือนเดิมขอให้เจ้าหน้าที่เทศกิจเขตจตุจักรจับปรับออกใบเสร็จค่าปรับสูงที่สุดด้วยและให้กวดขัดไม่ให้มีทุกเสาร์และอาทิตย์ด้วยอย่าปล่อยประ ละเลยหรือละเว้นการปฎิบัติหน้าที่เข้าข่ายความผิดมาตรา ทางกลุ่มเราขอให้ออกใบเสร็จใบต่อเรื่องร้องเรียนไม่ใช่ออกใบเสร็จมาแค่ใบแล้วใช้ตอบทั่วทั้งเขตจตุจักรเพราะเราร้องต่างกรรมต่างวาระกันในการร้องเรียน" ที่อยู่ "RHV แขวง จตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - รวมถึงชาวบ้านที่ได้เดินผ่านไปผ่านมาในละแวกนั้นด้วย" ที่อยู่ " ซอย ลาดพร้าว แยก แขวงพลับพลา เขตวังทองหลาง กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ถนน,  เสียงรบกวน : "ปัญหา ริมถนนดังกล่าว จุดสังเกต ตรงข้ามศูนย์การศึกษาและอนุรักษ์สิ่งแวดล้อมบางซื่อบริเวณพื้นที่ ด้านข้างสถานีขนส่งหมอชิต พบมีการจัดงานแสดงดนตรีหมอลำ ส่งเสียงดังรบกวน ปัจจุบันเวลา น เสียงดังรบกวนเป็นอย่างมาก สร้างความเดือนร้อนให้กับประชาชนที่พักอาศัยบริเวณใกล้เคียงเป็นอย่างมาก ถนน กำแพงเพชร จุดสังเกต พื้นที่ ด้านข้างสถานีขนส่งหมอชิต ถนนกำแพงเพชร แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร เขต จตุจักร " ที่อยู่ " ถนนกำแพงเพชร แขวงลาดยาว เขตจตุจักร กรุงเทพมหานคร แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"

# %%
test_docs_reranked = reranked_retriever.get_relevant_documents(test_query)
print(f'query : {test_query}')
print('-'*30)
for doc in test_docs_reranked[:10] :
  print(f'- {doc.page_content}')
# Out:
# query : เขตจตุจักรมีปัญหาเกี่ยวกับอะไรมากที่สุด?
# ------------------------------
# - ชนิด: ร้องเรียน : "ขอเรียนแจ้งปัญหาเกี่ยวกับการทำงานของผู้รับเหมา น่าจะเป็น TOT มีการทำงานที่ไม่เรียบร้อย ส่งผลให้ฝรั่งนักท่องเที่ยวหยุดถ่ายรูปหลายครั้ง ปัญหาเมือง" ที่อยู่ "Opposite Baan Klang Muang Lat Phrao แขวง จันทรเกษม เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ถนน : "ตลาดนัดจตุจักร เรียนผู้ว่ากทม ขอให้ตรวจสอบกรณีวันที่กค ณห้องประชุมตลาดนัดจตุจักร มีชมรมผู้ค้ากลุ่มนึงเข้ามาส่งจดหมายติดตาม คำสั่งจากปลัดกรุงเทพมหานคร ที่สั่งให้มีการทดลองจอดรถในตลาดนัดจตุจักรทั้งวันเป็นเวลาเดือนกค ถึง กย ว่าเป็นคำสั่งที่ชอบธรรมหรือไม่ และเอากฎระเบียบข้อไหนมารองรับ โดยผู้ค้ากลุ่มนี้อ้างว่าถ้าให้รถจอดริมถนนรอบตลาดนัดแล้วจะทำให้ลูกค้าเดินเข้าไปด้านในทำให้ด้านในขายดีขึ้น เป็นการพิจารณาที่รับฟังความข้างเดียว เป็นการแก้ปัญหาที่ไม่ตรงจุด ปัจจุบันการค้าขายรอบๆถนนในตลาดนัดจตุจักรกำลังเริ่มคึกคักหลังจากรัฐบาลมีมาตรการผ่อนปรนโรคโควิด นักท่องเที่ยวกำลังกลับมาจับจ่ายใช้สอย แต่คำสั่งดังกล่าวจะเป็นการทำลายวิถีอัตลักษณ์การเป็นตลาดนัดจตุจักรในสายตานักท่องเที่ยวหลักชาวต่างชาติ ขออย่าแก้ปัญหาที่ลูกค้าไม่เดินเข้าด้านในโดยการสร้างปัญหาให้ส่วนที่ดีอยู่แล้วให้เกิดผลเสียเพิ่มขึ้น การแก้ปัญหาที่ส่วนไหนลูกค้าไม่เดินเข้าไปต้องเพิ่มสิ่งดึงดูดที่น่าสนใจ ชักจูงจิตใจให้อยากที่จะเข้าไปด้านใน ไม่ใช่สร้างอุปสรรคขัดขวางเพื่อให้ต้องหลบไปอีกที่ ด้านในตลาดนัดจตุจักรมีหอนาฬิกาเป็นแลนด์มาร์ค มีพื้นที่ว่างลานเล่รอบหอนาฬิกา แต่การบริหารไม่สามารถใช้ศักยภาพจากจุดนี้ดึงลูกค้าเข้าด้านในได้ ถ้าสามารถใช้ประโยชน์จากส่วนนี้อย่างเต็มที่ จะเป็นการแก้ปัญหาภายในตลาดนัดจตุจักรที่ไม่กระทบกับส่วนรวมอื่นๆเลย" ที่อยู่ " ถนน กำแพงเพชร แขวง จตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - อย่างนี้ถือว่าปฎิบัติหน้าที่โดยมิชอบหรือไม่ อยากจะให้ทางพรรคก้าวไกล ในฐานะที่มีท่านสสเท่าพิภพเป็นสสเขตนี้ ช่วงดูแลด้วย" ที่อยู่ "สำนักงานเขตบางกอกใหญ่ แขวง วัดท่าพระ เขตบางกอกใหญ่ กรุงเทพมหานคร ประเทศไทย"
# - รวมถึงชาวบ้านที่ได้เดินผ่านไปผ่านมาในละแวกนั้นด้วย" ที่อยู่ " ซอย ลาดพร้าว แยก แขวงพลับพลา เขตวังทองหลาง กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ถนน,  เสียงรบกวน : "ปัญหา ริมถนนดังกล่าว จุดสังเกต ตรงข้ามศูนย์การศึกษาและอนุรักษ์สิ่งแวดล้อมบางซื่อบริเวณพื้นที่ ด้านข้างสถานีขนส่งหมอชิต พบมีการจัดงานแสดงดนตรีหมอลำ ส่งเสียงดังรบกวน ปัจจุบันเวลา น เสียงดังรบกวนเป็นอย่างมาก สร้างความเดือนร้อนให้กับประชาชนที่พักอาศัยบริเวณใกล้เคียงเป็นอย่างมาก ถนน กำแพงเพชร จุดสังเกต พื้นที่ ด้านข้างสถานีขนส่งหมอชิต ถนนกำแพงเพชร แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร เขต จตุจักร " ที่อยู่ " ถนนกำแพงเพชร แขวงลาดยาว เขตจตุจักร กรุงเทพมหานคร แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ต้นไม้,  แสงสว่าง,  ถนน,  คลอง : "ปัญหา ต้นไม้และสวนสาธารณะ เนื่องจาก ผู้แจ้งต้องการให้เจ้าหน้าที่ไปตัดแต่งต้นไม้ ซึ่งเป็นต้นไม้สาธารณะ ต้นไม้บดบังแสงสว่างจากไฟทาง จึงอยากให้ตัดแต่งต้นไม้ทั้ง ฝั่ง อยู่ตรงบริเวณหัวมุมบ้าน ต้นไม้ขึ้นสูงแล้วไปพันเกี่ยวกับสายไฟฟ้า ขอให้ดำเนินการตรวจสอบและแก้ไขปัญหานี้ด้วย จุดเกิดเหตุ สถานที่สำคัญ จุดสังเกต หมู่บ้านประชานิเวศน์ ฝั่งตรงข้ามกับคลองประปา บ้านผู้แจ้งจะอยู่ฝั่งเดียวกันกับสำนักงานประกันสังคม บ้านปูด้วยกระเบื้องสีส้ม บ้านเลขที่ ซอย ถนน เทศบาลรังสรรค์เหนือ แขวง ลาดยาว เขต จตุจักร " ที่อยู่ " ถนน เทศบาลนิมิตรเหนือ แขวงลาดยาว เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
# - หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตพญาไท ซอย อารีย์ แขวง พญาไท เขตพญาไท กรุงเทพมหานคร ซอย อารีย์ แขวง พญาไท เขตพญาไท กรุงเทพมหานคร ประเทศไทย"
# - การเป็นพยาน หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตบางแค ซอย กาญจนาภิเษก แยก แขวงบางแค เขตบางแค กรุงเทพมหานคร ซอย กาญจนาภิเษก แยก แขวงบางแค เขตบางแค กรุงเทพมหานคร ประเทศไทย"
# - หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตวังทองหลาง ซอย รามคำแหง แขวงพลับพลา เขตวังทองหลาง กรุงเทพมหานคร ซ รามคำแหง แขวงพลับพลา เขตวังทองหลาง กรุงเทพมหานคร ประเทศไทย"
# - ชนิด: ร้องเรียน,  ทางเท้า : "ป้ายโฆษณาคอนโดฯตั้งบนทางเท้ากลับมาอีกแล้วหายไปอาทิตย์เดียวก็มาเหมือนเดิมขอให้เจ้าหน้าที่เทศกิจเขตจตุจักรจับปรับออกใบเสร็จค่าปรับสูงที่สุดด้วยและให้กวดขัดไม่ให้มีทุกเสาร์และอาทิตย์ด้วยอย่าปล่อยประ ละเลยหรือละเว้นการปฎิบัติหน้าที่เข้าข่ายความผิดมาตรา ทางกลุ่มเราขอให้ออกใบเสร็จใบต่อเรื่องร้องเรียนไม่ใช่ออกใบเสร็จมาแค่ใบแล้วใช้ตอบทั่วทั้งเขตจตุจักรเพราะเราร้องต่างกรรมต่างวาระกันในการร้องเรียน" ที่อยู่ "RHV แขวง จตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"

# %%
for doc in test_docs_reranked[:10] :
  print(f'- {doc.metadata.get("ticket_id")}')
# Out:
# - 2024-4LTPRV
# - 2022-KL3AUW
# - 2022-DU7XZE
# - 2024-HEUK6W
# - 4P4NKX
# - 2RMUNW
# - EFJXKA
# - EAUC8C
# - 72NZDY
# - 2023-AWD87A

# %% [markdown]
# # Agentic RAG

# %%
from langgraph.graph import MessagesState, StateGraph

graph_builder = StateGraph(MessagesState)

# %%
from langchain_core.tools import tool

@tool(response_format="content")
def retrieve(query: str):
    """Retrieve information related to a query from a vector database of Traffy Fondue Dataset."""
    retrieved_docs = reranked_retriever.get_relevant_documents(query)
    serialized = "\n\n".join(
        (

            f"ticket_id: {doc.metadata.get('ticket_id')}\n"
            f"ประเภท: {doc.metadata.get('problem_type')}\n"
            f"สถานที่: {doc.metadata.get('address')}\n"
            f"รายละเอียด: {doc.page_content}"
        )
        for doc in retrieved_docs
    )
    return serialized

# %%
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage
from langgraph.prebuilt import ToolNode
from langchain_core.runnables import RunnableConfig

# Step 1: Generate an AIMessage that may include a tool-call to be sent.
def query_or_respond(state: MessagesState):
    """Generate tool call for retrieval or respond."""
    llm_with_tools = llm.bind_tools([retrieve])
    response = llm_with_tools.invoke(state["messages"])
    # MessagesState appends messages to state instead of overwriting
    return {"messages": [response]}


# Step 2: Execute the retrieval.
# The ToolNode is roughly analogous to:

# tools_by_name = {tool.name: tool for tool in tools}
# def tool_node(state: dict):
#     result = []
#     for tool_call in state["messages"][-1].tool_calls:
#         tool = tools_by_name[tool_call["name"]]
#         observation = tool.invoke(tool_call["args"])
#         result.append(ToolMessage(content=observation, tool_call_id=tool_call["id"]))
#     return {"messages": result}

tools = ToolNode([retrieve])


# Step 3: Generate a response using the retrieved content.
def generate(state: MessagesState):
    """Generate answer based on retrieved problem reports."""
    # Get retrieved ToolMessages
    recent_tool_messages = []
    for message in reversed(state["messages"]):
        if message.type == "tool":
            recent_tool_messages.append(message)
        else:
            break
    tool_messages = recent_tool_messages[::-1]

    # Format tool messages for structured data
    structured_entries = []
    for tool_msg in tool_messages:
        content = tool_msg.content  # This is the string returned from the tool
        structured_entries.append(content)

    docs_content = "\n\n".join(structured_entries)

    # System message prompt
    system_message_content = (
        "คุณเป็นผู้ช่วยที่เชี่ยวชาญในการตอบคำถามจากข้อมูลปัญหาที่ถูกรายงานผ่านระบบแจ้งปัญหา Traffy Fondue "
        "ข้อมูลแต่ละรายการจะประกอบด้วยประเภทของปัญหา, สถานที่ และรายละเอียดของปัญหา "
        "กรุณาตอบคำถามจากข้อมูลด้านล่าง ถ้าคุณไม่พบคำตอบที่ตรง ให้ตอบว่า 'ไม่พบข้อมูลที่เกี่ยวข้อง' และกล่าวถึงข้อมูลที่ใกล้เขียง เช่น สถานที่ใกล้เคียง หรือ ข้อมูลประเภทเดียวกัน"
        "เลือกเพียงข้อมูลที่มีความเกี่ยวข้องกับ คำถาม และ ตอบ ticket_id ที่เกี่ยวของมา หลังจบคำอธิบาย ใน format ticket_id : _id1, _id2, ..."
        "สรุปคำตอบออกมา และกล่าวถึงข้อมูลที่น่าสนใจ\n\n"
        f"{docs_content}"
    )

    conversation_messages = [
        message
        for message in state["messages"]
        if message.type in ("human", "system")
        or (message.type == "ai" and not message.tool_calls)
    ]

    prompt = [SystemMessage(system_message_content)] + conversation_messages

    # Run model
    response = llm.invoke(prompt)
    return {"messages": [response]}

# %%
from langgraph.graph import END
from langgraph.prebuilt import ToolNode, tools_condition

graph_builder.add_node(query_or_respond)
graph_builder.add_node(tools)
graph_builder.add_node(generate)

graph_builder.set_entry_point("query_or_respond")
graph_builder.add_conditional_edges(
    "query_or_respond",
    tools_condition,
    {END: END, "tools": "tools"},
)
graph_builder.add_edge("tools", "generate")
graph_builder.add_edge("generate", END)

graph = graph_builder.compile()

# %%
from IPython.display import Image, display

# display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)

# Specify an ID for the thread
config = {"configurable": {"thread_id": "abc123"}}

# %%
input_message = "Hello"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello
# ================================== Ai Message ==================================
#
# Hello! How can I help you today?

# %%
input_message = "What do u know"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What do u know
# ================================== Ai Message ==================================
#
# I have access to a vector database of Traffy Fondue Dataset, and I can retrieve information from it based on your queries. Just let me know what you're interested in!

# %%
input_message = "เขตจตุจักรมีปัญหาเกี่ยวกับอะไรมากที่สุด?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# เขตจตุจักรมีปัญหาเกี่ยวกับอะไรมากที่สุด?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve (f5ab0596-5f5a-4474-a559-735f9eb52ad1)
#  Call ID: f5ab0596-5f5a-4474-a559-735f9eb52ad1
#   Args:
#     query: What are the most common issues reported in Chatuchak district?
# ================================= Tool Message =================================
# Name: retrieve
#
# ticket_id: 2024-P7MEL6
# ประเภท: สายไฟ, ความปลอดภัย
# สถานที่: Soi Vibhavadi Rangsit 34 Chatuchak District Office 7th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok 10900 แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร 10900 ประเทศไทย
# รายละเอียด: ชนิด: สายไฟ,  ความปลอดภัย : "ซอยวิภาวดีมีต้นโพธิ์ใหญ่กิ่งหนาปกคลุม ทั้งกิ่งพันสายไฟเป็นอันตรายมากกับบริเวณเเถวนี้" ที่อยู่ "Soi Vibhavadi Rangsit Chatuchak District Office th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: TR9E3T
# ประเภท: ร้องเรียน, ถนน
# สถานที่: Soi Vibhavadi Rangsit 34, Chatuchak District Office, 7th Floor, Vibhavadi Rangsit Road, Chatuchak, Khet Chatuchak, Bangkok, 10900, แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร 10900 ประเทศไทย
# รายละเอียด: ชนิด: ร้องเรียน,  ถนน : "ปัญหาที่แจ้ง ประชาชนต้องการร้องเรียนเจ้าหน้าที่ชื่อ ลันภัทร มั่งคั่ง เป็นเจ้าหน้าที่ฝ่ายโยธา ของเขตจตุจักร เนื่องจากเจ้าหน้าที่ทำงานล้าช้า ประชาชนแจ้งเรื่องเข้ามาเมื่อวันที่ มีนาคม แจ้งเรื่องโกดังมีการก่อสร้างผิดรูปแบบ ขอให้ตรวจสอบ และ ประชาชนได้เข้าไปตามที่เขตหลายครั้ง ซึ่งเจ้าหน้าที่ตอบกลับมาว่ากำลังรอคัดเอกสาร แต่ ณ ปัจจุบัน เจ้าหน้าที่ได้แจ้งกลับทางประชาชนแล้วว่าได้ส่งเอกสารไปยังเจ้าของที่ดินแล้ว แต่ทั้งนี้ประชาชนยังต้องการที่จะร้องเรียนเนื่องจากเจ้าหน้าที่ดำเนินการล่าช้า จุดเกิดเหตุ ฝ่ายโยธา ของสำนักงานเขตจตุจักร ถนน ถนน วิภาวดีรังสิต แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร " ที่อยู่ "Soi Vibhavadi Rangsit Chatuchak District Office th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: KU76GB
# ประเภท: ต้นไม้, เสนอแนะ
# สถานที่: Soi Vibhavadi Rangsit 34, Chatuchak District Office, 7th Floor, Vibhavadi Rangsit Road, Chatuchak, Khet Chatuchak, Bangkok, 10900, แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร 10900 ประเทศไทย
# รายละเอียด: ชนิด: ต้นไม้,  เสนอแนะ : "ปัญหา ผู้แจ้งเป็นมัคคุเทศก์เสนอแนะให้เก็บขยะและตัดแต่งต้นไม้เพื่อเตรียมต้อนรับนักท่องเที่ยวที่จะมาช่วงปีใหม่ จุดสังเกต สถานีรถไฟราง ในเขตจตุจักร เขต จตุจักร " ที่อยู่ "Soi Vibhavadi Rangsit Chatuchak District Office th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: YCVM74
# ประเภท: ถนน
# สถานที่: Soi Vibhavadi Rangsit 34, Chatuchak District Office, 7th Floor, Vibhavadi Rangsit Road, Chatuchak, Khet Chatuchak, Bangkok, 10900, แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร 10900 ประเทศไทย
# รายละเอียด: ชนิด: ถนน : "ปัญหาผู้แจ้งว่า สำนักงานเขตจตุจักร เบอร์โทรศัพท์ของสำนักงานเขตไม่สามารถโทรติดต่อได้ โทรติดแต่ไม่มีเจ้าหน้าที่รับสาย พยายามโทรทั้งวันก็ติดต่อไม่ได้ ถนน วิภาวดีรังสิต ซอย แขวงจตุจักร เขตจตุจักร " ที่อยู่ "Soi Vibhavadi Rangsit Chatuchak District Office th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2023-MNM3CE
# ประเภท: เสนอแนะ
# สถานที่: Soi Vibhavadi Rangsit 34 Chatuchak District Office 7th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok 10900 แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร 10900 ประเทศไทย
# รายละเอียด: ชนิด: เสนอแนะ : "ผมเสนอแนะให้ส่งถึงสำนักงานเลขานุการผู้ว่าราชการกรุงเทพมหานครนะครับเรื่องดังภาพ" ที่อยู่ "Soi Vibhavadi Rangsit Chatuchak District Office th Floor Vibhavadi Rangsit Road Chatuchak Khet Chatuchak Bangkok แขวงจตุจักร เขตจตุจักร กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2022-62KQ23
# ประเภท: PM2.5
# สถานที่: 328 ซอย จรัญสนิทวงศ์ 75 แยก 19 แขวง บางพลัด เขตบางพลัด กรุงเทพมหานคร 10700 ประเทศไทย
# รายละเอียด: ชนิด: PM2.5 : "เผาไหม้ กลิ่นเหม็นมากPM สูงมาก วันนี้เค้าหลบถ่ายรูปไม่เห็น บ้านเดิมที่แจ้งไปไม่กี่วันก่อน แจ้งไป ทีแล้วค่ะ อากาศดีๆ แต่ตื่นมาเผาเกือบทุกเช้า ช่วยแก้ไขด้วยค่ะ ขอบคุณมากค่ะ" ที่อยู่ " ซอย จรัญสนิทวงศ์ แยก แขวง บางพลัด เขตบางพลัด กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-GLDVVL
# ประเภท: PM2.5
# สถานที่: บ้านเลขที่ 9 555 หมู่บ้านลัดดาวัลย์ แขวงบางระมาด เขตตลิ่งชัน กรุงเทพมหานคร 10170 ประเทศไทย
# รายละเอียด: ชนิด: PM2.5 : "มีควันเผาไหม้ เป็นจำนวนมาก ส่งกลิ่นสร้างผลกระทบอย่างรุนแรง ในช่องที่มีภาวะวิกฤ PM กลิ่นเผาไหม้มักจะเกิดในช่องเดือน ธันวาคม กุมภาพันธ์ของทุกปี รบกวนทางเจ้าหน้าที่เร่งตรวจสอบ และละเว้นการกระทำของผู้กระทำดังกล่าวให้หน่อยครับ ที่บ้านมีเด็กเล็ก แชะแม่บ้านที่ต้องนอนนอกอาคารที่ไม่มีแอร์ ต้องเปิดหน้าต่างตลอดเวลา รบกวนด้วยครับ" ที่อยู่ "บ้านเลขที่ หมู่บ้านลัดดาวัลย์ แขวงบางระมาด เขตตลิ่งชัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-L23U9M
# ประเภท: PM2.5
# สถานที่: 70/136 ซอย 7/1 แขวงคันนายาว เขตคันนายาว กรุงเทพมหานคร 10230 ประเทศไทย
# รายละเอียด: ชนิด: PM2.5 : "ในเวลานี้ เผาอีกแล้วค่ะ ถ้าบอกว่า ทำอาหาร ก็น่าจะทำดึกเกินไปนะคะ ช่วงนี้ PM เยอะ อยากให้ทางรัฐช่วยกัน กวดขันเรื่องเผากว่านี้ ค่ะ เขตที่ควรประสานงานชัดเจน ควรจะเป็นเขตคลองสามวา ด้วยนะคะ" ที่อยู่ " ซอย แขวงคันนายาว เขตคันนายาว กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 8W27DL
# ประเภท: เสียงรบกวน, ร้องเรียน
# สถานที่: สำนักงานเขตประเวศ เฉลิมพระเกีรยติ ร.9 ซอย 81 Prawet, Bangkok : 33 เฉลิมพระเกีรยติ ร.9 ซอย 81 แขวงประเวศ เขต ประเวศ กรุงเทพมหานคร 10250 ประเทศไทย
# รายละเอียด: หรือการให้ข้อมูลนั้น ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตประเวศ เฉลิมพระเกีรยติ ร ซอย Prawet Bangkok เฉลิมพระเกีรยติ ร ซอย แขวงประเวศ เขต ประเวศ กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: D37VN9
# ประเภท: กีดขวาง, เสียงรบกวน, ถนน, ร้องเรียน
# สถานที่: สำนักงานเขตพระโขนง Sukhumvit Road, แขวง พระโขนงใต้ Phra Khanong, Bangkok : Phra Khanong District Office, Sukhumvit Road, Bang Chak, Khet Phra Khanong, Bangkok, 10260, แขวงบางจาก เขตพระโขนง กรุงเทพมหานคร 10260 ประเทศไทย
# รายละเอียด: ศรท ศรท citydata" ที่อยู่ "สำนักงานเขตพระโขนง Sukhumvit Road แขวง พระโขนงใต้ Phra Khanong Bangkok Phra Khanong District Office Sukhumvit Road Bang Chak Khet Phra Khanong Bangkok แขวงบางจาก เขตพระโขนง กรุงเทพมหานคร ประเทศไทย"
# ================================== Ai Message ==================================
#
# จากข้อมูลที่มี พบว่าเขตจตุจักรมีปัญหาหลากหลายประเภท โดยปัญหาที่ถูกรายงานเข้ามามีดังนี้:
#
# *   **สายไฟและความปลอดภัย:** มีต้นโพธิ์ใหญ่กิ่งหนาปกคลุมสายไฟ ซึ่งเป็นอันตราย (ticket_id: 2024-P7MEL6)
# *   **ร้องเรียนเจ้าหน้าที่:** มีการร้องเรียนเจ้าหน้าที่ฝ่ายโยธาของเขตจตุจักรเนื่องจากทำงานล่าช้า (ticket_id: TR9E3T)
# *   **ข้อเสนอแนะ:** มีข้อเสนอแนะให้เก็บขยะและตัดแต่งต้นไม้เพื่อต้อนรับนักท่องเที่ยว (ticket_id: KU76GB)
# *   **ปัญหาการติดต่อสำนักงานเขต:** ไม่สามารถติดต่อสำนักงานเขตจตุจักรทางโทรศัพท์ได้ (ticket_id: YCVM74)
# *   **ข้อเสนอแนะทั่วไป:** มีข้อเสนอแนะที่ต้องการส่งถึงสำนักงานเลขานุการผู้ว่าราชการกรุงเทพมหานคร (ticket_id: 2023-MNM3CE)
#
# จากข้อมูลนี้ ปัญหาที่ถูกรายงานมากที่สุดในเขตจตุจักรคือปัญหาที่เกี่ยวข้องกับการบริการของสำนักงานเขต และข้อเสนอแนะต่างๆ
#
# ticket_id: 2024-P7MEL6, TR9E3T, KU76GB, YCVM74, 2023-MNM3CE
#
# สรุป: เขตจตุจักรมีปัญหาหลากหลาย ทั้งด้านความปลอดภัย (สายไฟ), การบริการของเจ้าหน้าที่, และข้อเสนอแนะต่างๆ ข้อมูลที่น่าสนใจคือมีการร้องเรียนเรื่องการติดต่อสำนักงานเขตไม่ได้ ซึ่งอาจส่งผลกระทบต่อการแก้ไขปัญหาอื่นๆ

# %%
input_message = "ขยะแถวปทุมวัน"

for step in graph.stream(
    {"messages": [
        {
          "role": "user",
          "content": input_message,
        }
    ]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# ขยะแถวปทุมวัน
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve (7b33ef92-5f08-4be1-a90d-6bab33484fc5)
#  Call ID: 7b33ef92-5f08-4be1-a90d-6bab33484fc5
#   Args:
#     query: garbage issue in Pathum Wan district
# ================================= Tool Message =================================
# Name: retrieve
#
# ticket_id: 2022-AXX8FD
# ประเภท:
# สถานที่: ติดกับร้าน Lawson 366 ร้านน้องนุ๊ก ข้างตลาดยิ่งรวย76 ตรงข้าม 108 ซอย ประชาอุทิศ 93 แขวง ทุ่งครุ เขตทุ่งครุ กรุงเทพมหานคร 10140 ประเทศไทย
# รายละเอียด: ชนิด:  : "ตัวอย่างการแจ้ง รบกวนมาเก็บขยะด้วยครับ" ที่อยู่ "ติดกับร้าน Lawson ร้านน้องนุ๊ก ข้างตลาดยิ่งรวย ตรงข้าม ซอย ประชาอุทิศ แขวง ทุ่งครุ เขตทุ่งครุ กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-L23U9M
# ประเภท: PM2.5
# สถานที่: 70/136 ซอย 7/1 แขวงคันนายาว เขตคันนายาว กรุงเทพมหานคร 10230 ประเทศไทย
# รายละเอียด: ชนิด: PM2.5 : "ในเวลานี้ เผาอีกแล้วค่ะ ถ้าบอกว่า ทำอาหาร ก็น่าจะทำดึกเกินไปนะคะ ช่วงนี้ PM เยอะ อยากให้ทางรัฐช่วยกัน กวดขันเรื่องเผากว่านี้ ค่ะ เขตที่ควรประสานงานชัดเจน ควรจะเป็นเขตคลองสามวา ด้วยนะคะ" ที่อยู่ " ซอย แขวงคันนายาว เขตคันนายาว กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2023-AAPP9N
# ประเภท: สัตว์จรจัด, ทางเท้า
# สถานที่: 448 Siam Kit Building Rama 1 Road Pathum Wan Khet Pathum Wan Bangkok 10330 แขวงปทุมวัน เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: สัตว์จรจัด,  ทางเท้า : "พบคนให้อาหารนกพิราบบริเวณแยกเฉลิมเผ่า เขตปทุมวัน บนพื้นทางเท้ามีเศษอาหารและมูลนกจำนวนหนึ่ง" ที่อยู่ " Siam Kit Building Rama Road Pathum Wan Khet Pathum Wan Bangkok แขวงปทุมวัน เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-4EY9TW
# ประเภท: ทางเท้า
# สถานที่: 448 Siam Kit Building Rama 1 Road Pathum Wan Khet Pathum Wan Bangkok 10330 แขวง ปทุมวัน เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: ทางเท้า : "คอบทางเท้าสีเลอะคราบดำไม่ชัดเจน" ที่อยู่ " Siam Kit Building Rama Road Pathum Wan Khet Pathum Wan Bangkok แขวง ปทุมวัน เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-8ACPDZ
# ประเภท: ทางเท้า
# สถานที่: 182-4 Soi Siam Square1 Rama I Road Pathum Wan Khet Pathum Wan Bangkok 10330 แขวงปทุมวัน เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: ทางเท้า : "ขายของบนทางเท้า" ที่อยู่ " Soi Siam Square Rama I Road Pathum Wan Khet Pathum Wan Bangkok แขวงปทุมวัน เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2023-E8MRXB
# ประเภท: คนจรจัด, ป้าย
# สถานที่: 448 Siam Kit Building Rama 1 Road Pathum Wan Khet Pathum Wan Bangkok 10330 แขวง ปทุมวัน เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: คนจรจัด,  ป้าย : "มีคนมาขอทานบนสะพานลอยทุกวันเลยค่ะ ทั้งๆที่มีป้ายห้ามแล้ว" ที่อยู่ " Siam Kit Building Rama Road Pathum Wan Khet Pathum Wan Bangkok แขวง ปทุมวัน เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-P7FDMC
# ประเภท: จราจร
# สถานที่: 448 Siam Kit Building Rama 1 Road Pathum Wan Khet Pathum Wan Bangkok 10330 แขวง ปทุมวัน เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: จราจร : "ป้อมตำรวจอยู่ด้านหน้า ติดไฟแดงมอเตอร์ไซย์ขับฝ่านฝืนกันหมดไร้ระเบียบ คุณพี่ตำรวจออกมาจากป้อมตำรวจหน่อยครับ ทำงานหน่อย" ที่อยู่ " Siam Kit Building Rama Road Pathum Wan Khet Pathum Wan Bangkok แขวง ปทุมวัน เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 4LZBDG
# ประเภท: ความสะอาด
# สถานที่: 347 ซอย สารภี 2 แขวงสมเด็จเจ้าพระยา เขตคลองสาน กรุงเทพมหานคร 10600 ประเทศไทย
# รายละเอียด: ชนิด: ความสะอาด : "This is israphap soi area The residents living around there need to be aware of not throwing trash in the canal Notice board sign should be there TraffyWebsite English" ที่อยู่ " ซอย สารภี แขวงสมเด็จเจ้าพระยา เขตคลองสาน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2022-C9XE8Q
# ประเภท:
# สถานที่: JCQX+5H2 แขวง ท่าข้าม เขตบางขุนเทียน กรุงเทพมหานคร 10150 ประเทศไทย
# รายละเอียด: ชนิด:  : "ตัวอย่างการแจ้ง รบกวนมาเก็บขยะด้วยครับ" ที่อยู่ "JCQXH แขวง ท่าข้าม เขตบางขุนเทียน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2BHM9L
# ประเภท: ความสะอาด
# สถานที่: 641/1, Sinakharin Road, Suan Luang, Khet Suan Luang แขวงหนองบอน เขต ประเวศ กรุงเทพมหานคร 10250 ประเทศไทย
# รายละเอียด: ชนิด: ความสะอาด : "Motorcycle riding on footpath No plate What are the police doing Too many motorcycles without plates TraffyWebsite English" ที่อยู่ " Sinakharin Road Suan Luang Khet Suan Luang แขวงหนองบอน เขต ประเวศ กรุงเทพมหานคร ประเทศไทย"
# ================================== Ai Message ==================================
#
# จากข้อมูลที่ให้มา ไม่มีข้อมูลปัญหาขยะในเขตปทุมวันโดยตรง แต่มีข้อมูลที่เกี่ยวข้องกับปัญหาอื่น ๆ ในพื้นที่ปทุมวันดังนี้:
#
# *   **สัตว์จรจัดและทางเท้า:** พบคนให้อาหารนกพิราบบริเวณแยกเฉลิมเผ่า ทำให้มีเศษอาหารและมูลนกบนทางเท้า (ticket_id: 2023-AAPP9N)
# *   **ทางเท้า:** คอบทางเท้าสีเลอะคราบดำไม่ชัดเจน (ticket_id: 2024-4EY9TW) และมีการขายของบนทางเท้า (ticket_id: 2024-8ACPDZ)
# *   **คนจรจัดและป้าย:** มีคนมาขอทานบนสะพานลอย ทั้ง ๆ ที่มีป้ายห้ามแล้ว (ticket_id: 2023-E8MRXB)
# *   **จราจร:** มอเตอร์ไซค์ฝ่าฝืนไฟแดงบริเวณหน้าป้อมตำรวจ (ticket_id: 2024-P7FDMC)
#
# ดังนั้น ถึงแม้จะไม่มีข้อมูลขยะโดยตรง แต่ก็มีปัญหาอื่น ๆ ที่ส่งผลต่อความสะอาดและความเป็นระเบียบเรียบร้อยของทางเท้าในเขตปทุมวัน
#
# ticket_id: 2023-AAPP9N, 2024-4EY9TW, 2024-8ACPDZ, 2023-E8MRXB, 2024-P7FDMC
#
# สรุป: ไม่พบข้อมูลปัญหาขยะโดยตรงในเขตปทุมวัน แต่พบปัญหาอื่น ๆ ที่เกี่ยวข้องกับทางเท้า สัตว์จรจัด และการจราจร ซึ่งอาจส่งผลต่อความสะอาดและความเป็นระเบียบเรียบร้อยของพื้นที่ ข้อมูลที่น่าสนใจคือปัญหาการขายของบนทางเท้าและการให้อาหารนกพิราบ ซึ่งอาจก่อให้เกิดปัญหาขยะตามมาได้

# %%
input_message = "ถ้าเกิดปัญหาทางเท้าเสียหายในเขตบางนา โมเดลจะสามารถหาข้อมูลที่เกี่ยวข้องได้หรือไม่?"

for step in graph.stream(
    {"messages": [{"role": "user", "content": input_message}]},
    stream_mode="values",
    config=config,
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# ถ้าเกิดปัญหาทางเท้าเสียหายในเขตบางนา โมเดลจะสามารถหาข้อมูลที่เกี่ยวข้องได้หรือไม่?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve (2cbc51d9-b541-4468-96f8-6b5679e18060)
#  Call ID: 2cbc51d9-b541-4468-96f8-6b5679e18060
#   Args:
#     query: damaged footpath in Bang Na district
# ================================= Tool Message =================================
# Name: retrieve
#
# ticket_id: 2024-6QEMGX
# ประเภท: การเดินทาง, ร้องเรียน
# สถานที่: ชุมชนหลักสี่พัฒนา 99 แขวงตลาดบางเขน เขตหลักสี่ กรุงเทพมหานคร 10210 ประเทศไทย
# รายละเอียด: ฅนแก่ ฅนพิการจะได้ไม่ต้องไต่ฃึ้นบันไดกว่าฃั้นเพื่อไปฃึ้นรถไฟทางไกลบนทางยกระดับและรถไฟฟ้าสายสีแดงให้ลำบากเหมือนในวันนี้อีกต่อไปด้วยค่ะ" ที่อยู่ "ชุมชนหลักสี่พัฒนา แขวงตลาดบางเขน เขตหลักสี่ กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2022-MLG89A
# ประเภท: ถนน, น้ำท่วม
# สถานที่: 211/78 Bang Na - Trat Road Bang Na Khet Bang Na Bangkok 10260 แขวง บางนา เขตบางนา กรุงเทพมหานคร 10260 ประเทศไทย
# รายละเอียด: ชนิด: ถนน,  น้ำท่วม : "ปัญหาฟุตบาทเป็นหลุมบ่อลึก ฝนตกน้ำขัง ต้องเดินขอบติดถนน เสี่ยงอุบัติเหตุ" ที่อยู่ " Bang Na Trat Road Bang Na Khet Bang Na Bangkok แขวง บางนา เขตบางนา กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-D9T3X8
# ประเภท: กีดขวาง, ป้าย
# สถานที่: 211/78 Bang Na - Trat Road Bang Na Khet Bang Na Bangkok 10260 บางนาเหนือ เขตบางนา กรุงเทพมหานคร 10260 ประเทศไทย
# รายละเอียด: ชนิด: กีดขวาง,  ป้าย : "ป้ายขวางทางเท้า" ที่อยู่ " Bang Na Trat Road Bang Na Khet Bang Na Bangkok บางนาเหนือ เขตบางนา กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-CQHYDR
# ประเภท: ทางเท้า
# สถานที่: 21/253 ถ.นวลจันทร์ แขวงนวลจันทร์ เขตบึงกุ่ม กรุงเทพมหานคร 10230 ประเทศไทย
# รายละเอียด: ชนิด: ทางเท้า : "บ้านเลขที่ ซอยนวลจันทร์ ย้ายเครื่องพิมพ์ขนาดใหญ่ลักษณะเครื่องที่ใช้ทำงานในโรงงานอุตสาหกรรมเข้ามาในบ้านดังกล่าว ทันทีที่ย้ายเข้ามามีกลิ่นคล้ายน้ำมันเครื่อง กลิ่นหมึกพิมพ์ กลิ่นสารเคมีรั่วออกมาเป็นกลิ่นที่รุนแรงมากบ้านข้างเคียงได้กลิ่นรุนแรงไม่สามารถอยู่ได้หายใจเข้าไปเกิดอาการหอบหืด หายใจไม่ออก กลิ่นเข้าไปในห้องทุกห้องของบ้านข้างเคียงเมื่อเปิดแอร์ในบ้านมีแต่กลิ่นสารเคมี ซึ่งลักษณะเครื่องจักรที่นำมาเป็นลักษณะเครื่องจักรที่ใช้ในโรงงานอุตสาหกรรมไม่สามารถนำมาใช้ในหมู่บ้านที่อยู่ในชุมชนและมีผู้พักอาศัยทุกหลังได้ แนวทางแก้ไขให้ผู้ที่ขนย้ายเครื่องพิมพ์เข้ามารีบย้ายเครื่องจักรขนาดใหญ่ดังกล่าวออกโดยด่วน โดยหน่วยงานให้เจ้าหน้าที่เข้ามาประสานติดต่อแจ้งให้ย้ายออกไปจากพื้นที่โดยเร็วเพราะสร้างมลพิษทางกลิ่นที่รุนแรงมาก มีปัญหาต่อระบบทางเดินหายใจและระบบหลอดเลือด บ้านที่พักอาศัยข้างเคียงมีแต่เด็กอยู่ทั้งนั้นตอนนี้อยู่ด้วยความลำบากมากๆหายใจสูดลิ่นเหม็นตลอดเวลา ตอนนี้มีกลิ่นให้ดมทั้งตอนกลางวันและกลางคืนนอนกันแทบไม่ได้ช่วยมาแจ้งให้เจ้าของบ้านรีบย้ายออกโดยด่วนเพราะเครื่องจักรอุตสาหกรรมหมึกพิมพ์สร้างกลิ่นมลพิษออกมาอย่างรุนแรง ช่วยส่งเจ้าหน้าที่มาอย่างเร่งด่วน" ที่อยู่ " ถนวลจันทร์ แขวงนวลจันทร์ เขตบึงกุ่ม กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: TMZBUD
# ประเภท: น้ำท่วม, ถนน
# สถานที่: 111, Big C Bang Na, 1st Floor, Bang Na-Trad Road, Bang Na, Khet Bang Na, Bangkok, 10260, บางนาเหนือ เขตบางนา กรุงเทพมหานคร 10260 ประเทศไทย
# รายละเอียด: ชนิด: น้ำท่วม,  ถนน : "ปัญหา ภายในซอยดังกล่าว บริเวณข้างเซ็นทรัลบางนา พบมีน้ำท่วมสูง รถเล็กไม่สามารถสัญจรได้ ซอย บางนาตราด ถนน บางนาตราด เขต บางนา " ที่อยู่ " Big C Bang Na st Floor Bang NaTrad Road Bang Na Khet Bang Na Bangkok บางนาเหนือ เขตบางนา กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2023-3DGU3V
# ประเภท: การเดินทาง
# สถานที่: 254 ถ. พญาไท แขวงวังใหม่ เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: การเดินทาง : "เบรลล์บล็อกใช้งานไม่ได้จริง เนื่องจากมีท่อขั้น และออกแบบมาให้หยุดเดินทั้ง ๆ ที่เป็นทางที่ควรไปต่อ ยากต่อผู้พิการในการเดินทาง" ที่อยู่ " ถ พญาไท แขวงวังใหม่ เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2022-CMCPAZ
# ประเภท: กีดขวาง
# สถานที่: 794 ถนน อุดมสุข Bang Na Nuea Sub- district แขวง บางนา เขตบางนา กรุงเทพมหานคร 10260 ประเทศไทย
# รายละเอียด: ชนิด: กีดขวาง : "ตั้งป้ายกีดขวางทางเท้า" ที่อยู่ " ถนน อุดมสุข Bang Na Nuea Sub district แขวง บางนา เขตบางนา กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2024-GRN2TQ
# ประเภท: ทางเท้า
# สถานที่: 207/20 Lotus Express Phatthanakan Road Prawet Khet Prawet Bangkok 10250 แขวง ประเวศ เขต ประเวศ กรุงเทพมหานคร 10250 ประเทศไทย
# รายละเอียด: ชนิด: ทางเท้า : "อ้างอิง HHKKPU มีการปิดงานแต่ยังพบปัญหาอยู่ ซึ่งเทศกิจ ปิดงานได้แย่มากเพราะ ระบุเวลาที่แผงลอยขายของบนฟุทบาทเวลาประมาณ แต่เทศกิจไปตอนบ่ายๆซึ่งผู้ค้ายังไม่ตั้งร้านเลย ปัจจุบัน ยังพบ ร้านข้าวแกงถุง ร้านบังขายโรตี ร้านลูกชิ้นย่าง ลังน้ำแข็งของร้านดอกไม้ แผงล๊อตตารี่ มอเตอร์ไซพ่วงข้าง ขายส้มตำไก่ย่าง รบกวนมาตรวจสอบด้วยคะมาให้ตรงเวลาที่เปิดร้าน มาให้เจอผู้ค้า ไม่ใช่มาเพื่อ ปิดงานถ่ายรูป" ที่อยู่ " Lotus Express Phatthanakan Road Prawet Khet Prawet Bangkok แขวง ประเวศ เขต ประเวศ กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: UEZGYV
# ประเภท: ถนน
# สถานที่: 111, Big C Bang Na, 1st Floor, Bang Na-Trad Road, Bang Na, Khet Bang Na, Bangkok, 10260, บางนาเหนือ เขตบางนา กรุงเทพมหานคร 10260 ประเทศไทย
# รายละเอียด: ชนิด: ถนน : "ปัญหา ถนนชำรุดเป็นหลุมเป็นบ่อ พื้นไม่เรียบพบเห็นมานานเป็นปีแล้ว ซอย บางนาตราด ถนน บางนาตราด จุดสังเกต เข้าซอยดังกล่าวไปประมาณ เมตรอยู่หลังเซ็นทรัลบางนา บริเวณหน้าร้าน Cockpit เขต บางนา " ที่อยู่ " Big C Bang Na st Floor Bang NaTrad Road Bang Na Khet Bang Na Bangkok บางนาเหนือ เขตบางนา กรุงเทพมหานคร ประเทศไทย"
#
# ticket_id: 2022-MR3LUT
# ประเภท: ทางเท้า
# สถานที่: แยกเพลินจิต,โรงแรมเซ็นเตอร์พ้อยท์ แขวง ลุมพินี เขตปทุมวัน กรุงเทพมหานคร 10330 ประเทศไทย
# รายละเอียด: ชนิด: ทางเท้า : "งานแก้ไขทางเท้า BTS เพลินจิต ทางเท้าใต้สถานีรถไฟฟ้าเพลินจิต ฝั่งซอยนายเลิศ สัญจรไม่ได้ จุด ขอให้เร่งแก้ไขโดยด่วน ตาม Google Street View ครับ httpswwwgooglecommapsayhtdatamemsHpahZoTbSuhqsWXyIgeiiauthuser httpswwwgooglecommapsayhtdatamemsenNAdJEfqYteWLogeiiauthuser ภาพ httpswwwfacebookcomAccessibilityIsFreedompostspfbidLidcKzwArVqvhGyitrUyqQkNrDnvLWdyZqdgESTsVgcBcHGQPUul" ที่อยู่ "แยกเพลินจิตโรงแรมเซ็นเตอร์พ้อยท์ แขวง ลุมพินี เขตปทุมวัน กรุงเทพมหานคร ประเทศไทย"
# ================================== Ai Message ==================================
#
# จากข้อมูลที่มีอยู่ สามารถค้นหาข้อมูลที่เกี่ยวข้องกับปัญหาทางเท้าในเขตบางนาได้ ดังนี้:
#
# *   **ทางเท้า:** พบปัญหาฟุตบาทเป็นหลุมบ่อลึก ฝนตกน้ำขัง บริเวณถนนบางนา-ตราด (ticket_id: 2022-MLG89A)
# *   **กีดขวาง:** พบป้ายขวางทางเท้า บริเวณถนนบางนา-ตราด (ticket_id: 2024-D9T3X8) และมีการตั้งป้ายกีดขวางทางเท้า บริเวณถนนอุดมสุข (ticket_id: 2022-CMCPAZ)
#
# ดังนั้น หากเกิดปัญหาทางเท้าเสียหายในเขตบางนา โมเดลสามารถค้นหาข้อมูลที่เกี่ยวข้องได้ โดยเฉพาะปัญหาเกี่ยวกับหลุมบ่อและการกีดขวางทางเท้า
#
# ticket_id: 2022-MLG89A, 2024-D9T3X8, 2022-CMCPAZ
#
# สรุป: โมเดลสามารถค้นหาข้อมูลที่เกี่ยวข้องกับปัญหาทางเท้าในเขตบางนาได้ โดยเฉพาะปัญหาเกี่ยวกับหลุมบ่อและการกีดขวางทางเท้า ข้อมูลที่น่าสนใจคือปัญหาเหล่านี้เกิดขึ้นบนถนนสายหลักอย่างบางนา-ตราด และถนนอุดมสุข ซึ่งอาจส่งผลกระทบต่อการสัญจรของประชาชนจำนวนมาก
